# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.linspace(-1,-5,100)
t=np.linspace(1,10,100)
v=[a[i]*ti for i, ti in enumerate(t)]

plt.plot(t,v)
plt.xlabel("time")
plt.ylabel("speed")
plt.title("Decceleration at an increasing rate")
plt.show()

# %%
a=np.linspace(0,600,100)
t=np.linspace(1,10,100)
v=[a[i]*ti + 20 for i, ti in enumerate(t)]

plt.plot(t,v)
plt.xlabel("time")
plt.ylabel("speed")
plt.title("Increasing acceleration")
plt.show()

# %%
a=np.linspace(-10,-4,100)
t=np.linspace(1,10,100)
v=[a[i]*ti for i, ti in enumerate(t)]

plt.plot(t,v)
plt.xlabel("time")
plt.ylabel("speed")
plt.title("Negative acceleration (decceleration) increasing")
plt.show()

# %%
import math
for i in range(5):
    print(math.factorial(i))
# Out:
# 1
# 1
# 2
# 6
# 24
